# %%
# !pip install transformers accelerate bitsandbytes -q

from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

MODEL = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForCausalLM.from_pretrained(
    MODEL,
    device_map="auto",   # usa GPU se houver
    torch_dtype=torch.float16
)

def resumir_filme(filme):
    prompt = f"""
Resuma o filme "{filme}" em 5 frases,
explicando a premissa mas evitando spoilers importantes.
"""

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    output = model.generate(
        **inputs,
        max_new_tokens=200,
        temperature=0.5
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

print(resumir_filme("Vingadores: Ultimato"))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 10.0 MB/s eta 0:00:00
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Resuma o filme "Vingadores: Ultimato" em 5 frases,
# explicando a premissa mas evitando spoilers importantes.
# 1. O Vingador Ant-Man e sua amiga Wasp se unem para combater Thanos, que está planejando destruir os universos.
# 2. A equipe de super-heróis é reforçada por outros personagens icônicos como Thor, Hulk e Capitão América.
# 3. Os vilões Loki e Galactus também aparecem, aumentando ainda mais a complexidade da batalha.
# 4. O resultado final resulta na morte de Thanos, libertando uma nova era de paz no universo Marvel.
# 5. O filme celebra a união de diferentes universos e mostra como a força combinada pode vencer adversários poderosos. Resumindo:
#
# O Vingadores: Ultimato une diversos heróis ao redor do mundo, incluindo personagens icônicos como Thor, Hulk e Capitão América, para enfrentar Thanos, um vilão poderoso. Além
